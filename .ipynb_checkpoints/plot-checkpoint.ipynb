# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "01252022_202153_10000.pkl"
df = pd.read_pickle(f"./df/{file}")
df
# Out:
#                          no_error undetected_error corrected_error  \
# size physical_error_rate
# 5    0.3                      403                5            8522
#      0.4                       97                6            7566
#      0.5                       23                0            5963
#      0.6                        1                4            4440
#      0.7                        2                0            3048
# 7    0.3                       16                0            9332
#      0.4                        2                0            8211
#      0.5                        0                0            6414
#      0.6                        0                0            4660
#      0.7                        0                0            3315
# 9    0.3                        1                0            9648
#      0.4                        0                0            8562
#      0.5                        0                0            6982
#      0.6                        0                0            5188
#      0.7                        0                0            3494
# 11   0.3                        0                0            9795
#      0.4                        0                0            9023
#      0.5                        0                0            7432
#      0.6                        0                0            5648
#      0.7                        0                0            3856
#
#                          uncorrected_error effective_error_rate  \
# size physical_error_rate
# 5    0.3                              1070                0.225
#      0.4                              2331                  0.3
#      0.5                              4014                0.375
#      0.6                              5555                 0.45
#      0.7                              6950                0.525
# 7    0.3                               652                0.225
#      0.4                              1787                  0.3
#      0.5                              3586                0.375
#      0.6                              5340                 0.45
#      0.7                              6685                0.525
# 9    0.3                               351                0.225
#      0.4                              1438                  0.3
#      0.5                              3018                0.375
#      0.6                              4812                 0.45
#      0.7                              6506                0.525
# 11   0.3                               205                0.225
#      0.4                               977                  0.3
#      0.5                              2568                0.375
#      0.6                              4352                 0.45
#      0.7                              6144                0.525
#
#                          logical_error_rate  better
# size physical_error_rate
# 5    0.3                             0.1075    True
#      0.4                             0.2337    True
#      0.5                             0.4014   False
#      0.6                             0.5559   False
#      0.7                              0.695   False
# 7    0.3                             0.0652    True
#      0.4                             0.1787    True
#      0.5                             0.3586    True
#      0.6                              0.534   False
#      0.7                             0.6685   False
# 9    0.3                             0.0351    True
#      0.4                             0.1438    True
#      0.5                             0.3018    True
#      0.6                             0.4812   False
#      0.7                             0.6506   False
# 11   0.3                             0.0205    True
#      0.4                             0.0977    True
#      0.5                             0.2568    True
#      0.6                             0.4352    True
#      0.7                             0.6144   False

# %%
num = sum(df.loc[(5,0.3), ["no_error", "undetected_error", "corrected_error", "uncorrected_error"]])

# %%
plt.figure()
physical_error_rate = sorted(list(set(df.index.get_level_values("physical_error_rate"))))
plt.title(f"Logical Error Rate vs Physical Erasure Rate: {num:n} Simulations")
plt.xlabel("Physical Erasure Rate")
plt.ylabel("Logical Error Rate")
for size in sorted(list(set(df.index.get_level_values("size")))):
#     plt.plot(physical_error_rate,df.loc[size, "logical_error_rate"], "--o", label = f"Size = {size}")
    plt.plot(physical_error_rate,df.loc[size, "uncorrected_error"]/(df.loc[size, "uncorrected_error"]+df.loc[size, "corrected_error"]), "--o", label = f"Size = {size}")
# plt.plot(physical_error_rate, df.loc[size,"effective_error_rate"], label = "Effective Error Rate")
plt.legend()
plt.savefig(f"{file}.jpg")
plt.show()
